# %%
import fiftyone as fo
import fiftyone.zoo as foz

# %%
dataset = foz.load_zoo_dataset("quickstart")
session = fo.launch_app(dataset, auto=False)
# Out:
# Dataset already downloaded
# Loading existing dataset 'quickstart'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use
# Session launched. Run `session.show()` to open the App in a cell output.

# %%
dataset
# Out:
# Name:        quickstart
# Media type:  image
# Num samples: 200
# Persistent:  False
# Tags:        []
# Sample fields:
#     id:               fiftyone.core.fields.ObjectIdField
#     filepath:         fiftyone.core.fields.StringField
#     tags:             fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:         fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     created_at:       fiftyone.core.fields.DateTimeField
#     last_modified_at: fiftyone.core.fields.DateTimeField
#     ground_truth:     fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     uniqueness:       fiftyone.core.fields.FloatField
#     predictions:      fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)

# %%
import fiftyone.brain as fob

results = fob.compute_visualization(
    dataset,
    method="umap",  # "umap", "tsne", "pca", etc
    brain_key="test_umap",
)
# Out:
# Computing embeddings...
#  100% |█████████████████| 200/200 [2.4s elapsed, 0s remaining, 128.3 samples/s]
# Generating visualization...
# UMAP( verbose=True)
# Fri Oct 31 07:41:30 2025 Construct fuzzy simplicial set
# Fri Oct 31 07:41:30 2025 Finding Nearest Neighbors
# Fri Oct 31 07:41:33 2025 Finished Nearest Neighbor Search
# Fri Oct 31 07:41:34 2025 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Fri Oct 31 07:41:35 2025 Finished embedding

# %%
# Image embeddings

fob.compute_visualization(dataset, brain_key="img_viz")


# Object patch embeddings

fob.compute_visualization(

    dataset, patches_field="ground_truth", brain_key="gt_viz"

)
# Out:
# Computing embeddings...
#  100% |█████████████████| 200/200 [1.4s elapsed, 0s remaining, 169.7 samples/s]
# Generating visualization...
# UMAP( verbose=True)
# Fri Oct 31 07:53:48 2025 Construct fuzzy simplicial set
# Fri Oct 31 07:53:48 2025 Finding Nearest Neighbors
# Fri Oct 31 07:53:48 2025 Finished Nearest Neighbor Search
# Fri Oct 31 07:53:48 2025 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Fri Oct 31 07:53:48 2025 Finished embedding
# Computing patch embeddings...
#  100% |█████████████████| 200/200 [11.1s elapsed, 0s remaining, 18.4 samples/s]
# Generating visualization...
# UMAP( verbose=True)
# Fri Oct 31 07:54:00 2025 Construct fuzzy simplicial set
# Fri Oct 31 07:54:00 2025 Finding Nearest Neighbors
# Fri Oct 31 07:54:00 2025 Finished Nearest Neighbor Search
# Fri Oct 31 07:54:00 2025 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Fri Oct 31 07:54:01 2025 Finished embedding
